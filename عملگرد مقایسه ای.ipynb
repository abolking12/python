# %%
88<55
# Out:
# False

# %%
58>66
# Out:
# False

# %%
85<=55
# Out:
# False

# %%
854>=12
# Out:
# True

# %%
547==85
# Out:
# False

# %%
865!=55
# Out:
# True

# %%
85<556
# Out:
# True

# %%
858!=85
# Out:
# True

# %%
854==55
# Out:
# False

# %%
858>=856
# Out:
# True
