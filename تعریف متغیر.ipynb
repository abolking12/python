# %%
w=2
e=4
r=12
d=48
s=66
f=456
v=45
k=876
p=7964
z=456

# %%
w+55
# Out:
# 57

# %%
w-89
# Out:
# -87

# %%
w*85
# Out:
# 170

# %%
w/56
# Out:
# 0.03571428571428571

# %%
w//86
# Out:
# 0

# %%
w**856
# Out:
# 

# %%
w%568
# Out:
# 2

# %%
w==55
# Out:
# False

# %%
w!=569
# Out:
# True

# %%
w<898
# Out:
# True

# %%
w>574
# Out:
# False

# %%
w<=55
# Out:
# True

# %%
w>=78
# Out:
# False

# %%
e+58
# Out:
# 62

# %%
e-457
# Out:
# -453

# %%
e*847
# Out:
# 3388

# %%
e/56
# Out:
# 0.07142857142857142

# %%
e//85
# Out:
# 0

# %%
e%875
# Out:
# 4

# %%
e**4
# Out:
# 256

# %%
e==558
# Out:
# False

# %%
e!=564
# Out:
# True

# %%
e<696
# Out:
# True

# %%
e>578
# Out:
# False

# %%
e>=57
# Out:
# False

# %%
e<=655
# Out:
# True

# %%
r+745
# Out:
# 757

# %%
r-54
# Out:
# -42

# %%
r*44
# Out:
# 528

# %%
r/58
# Out:
# 0.20689655172413793

# %%
r//548
# Out:
# 0

# %%
r%659
# Out:
# 12

# %%
r**78
# Out:
# 1500158654173824244445901346699938405046228479331843405109463057079932580570809237504

# %%
r
