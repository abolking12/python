# %%
a= 1
s= 2
d= 2.3
f= 3.5
g= False
h= True
j= "ali"
k= "mamad"
l= 12
q= 12.9

# %%
type(a)
# Out:
# int

# %%
type(s)
# Out:
# int

# %%
type(d)
# Out:
# float

# %%
type(f)
# Out:
# float

# %%
type(g)
# Out:
# bool

# %%
type(h)
# Out:
# bool

# %%
type(j)
# Out:
# str

# %%
type(k)
# Out:
# str

# %%
type(l)
# Out:
# int

# %%
type(q)
# Out:
# float

# %%
int(a)
# Out:
# 1

# %%
int(s)
# Out:
# 2

# %%
int(d)
# Out:
# 2

# %%
int(f)
# Out:
# 3

# %%
int(g)
# Out:
# 0

# %%
int(h)
# Out:
# 1

# %%
int(j)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 int(j)
#
# ValueError: invalid literal for int() with base 10: 'ali'

# %%
int(k)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 int(k)
#
# ValueError: invalid literal for int() with base 10: 'mamad'

# %%
int(l)
# Out:
# 12

# %%
int(q)
# Out:
# 12

# %%
float(a)
# Out:
# 1.0

# %%
float(s)
# Out:
# 2.0

# %%
float(d)
# Out:
# 2.3

# %%
float(f)
# Out:
# 3.5

# %%
float(g)
# Out:
# 0.0

# %%
float(h)
# Out:
# 1.0

# %%
float(j)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 float(j)
#
# ValueError: could not convert string to float: 'ali'

# %%
float(k)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 float(k)
#
# ValueError: could not convert string to float: 'mamad'

# %%
float(l)
# Out:
# 12.0

# %%
float(q)
# Out:
# 12.9

# %%
bool(a)
# Out:
# True

# %%
bool(s)
# Out:
# True

# %%
bool(d)
# Out:
# True

# %%
bool(f)
# Out:
# True

# %%
bool(g)
# Out:
# False

# %%
bool(h)
# Out:
# True

# %%
bool(j)
# Out:
# True

# %%
bool(k)
# Out:
# True

# %%
bool(l)
# Out:
# True

# %%
bool(q)
# Out:
# True

# %%
str(a)
# Out:
# '1'

# %%
str(s)
# Out:
# '2'

# %%
str(d)
# Out:
# '2.3'

# %%
str(f)
# Out:
# '3.5'

# %%
str(g)
# Out:
# 'False'

# %%
str(h)
# Out:
# 'True'

# %%
str(h)
# Out:
# 'True'

# %%
str(j)
# Out:
# 'ali'

# %%
str(k)
# Out:
# 'mamad'

# %%
str(l)
# Out:
# '12'

# %%
str(q)
# Out:
# '12.9'
